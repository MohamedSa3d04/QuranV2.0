# %%
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_csv('./hafs_smart_v8.csv')

# %%
df
# Out:
#       Unnamed: 0    id sura_name_ar                                  aya_text  \
# 0              0     1    الفَاتِحة   بِسْمِ اللَّهِ الرَّحْمَـٰنِ الرَّحِيمِ
# 1              1     2    الفَاتِحة     الْحَمْدُ لِلَّهِ رَبِّ الْعَالَمِينَ
# 2              2     3    الفَاتِحة                  الرَّحْمَـٰنِ الرَّحِيمِ
# 3              3     4    الفَاتِحة                   مَالِكِ يَوْمِ الدِّينِ
# 4              4     5    الفَاتِحة  إِيَّاكَ نَعْبُدُ وَإِيَّاكَ نَسْتَعِينُ
# ...          ...   ...          ...                                       ...
# 6231        6231  6232      النَّاس                           مَلِكِ النَّاسِ
# 6232        6232  6233      النَّاس                         إِلَـٰهِ النَّاسِ
# 6233        6233  6234      النَّاس        مِن شَرِّ الْوَسْوَاسِ الْخَنَّاسِ
# 6234        6234  6235      النَّاس   الَّذِي يُوَسْوِسُ فِي صُدُورِ النَّاسِ
# 6235        6235  6236      النَّاس                مِنَ الْجِنَّةِ وَالنَّاسِ
#
# ...

# %%
x = np.random.choice(df.index)

# %%
df.loc[x, 'aya_text']
# Out:
# 'وَمِنَ النَّاسِ مَن يُجَادِلُ فِي اللَّهِ بِغَيْرِ عِلْمٍ وَيَتَّبِعُ كُلَّ شَيْطَانٍ مَّرِيدٍ'
